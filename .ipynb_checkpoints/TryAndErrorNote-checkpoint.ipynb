# %%
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

# %%
ls
# Out:
# RegularSizedCatsImages.npy  TryAndErrorNote.ipynb
# RegularSizedDogsImages.npy  __pycache__/
# ResizedCatImg.npy           model.py
# ResizedDogImg.npy           test_set/
# SetUpTheOriginalData.py     training_set/

# %%
_dogs = np.load('RegularSizedDogsImages.npy')
_cats = np.load('RegularSizedCatsImages.npy')

# %%
print(type(_dogs))
print(_dogs.shape)
print(_dogs[0][0][0])
print(type(_cats))
print(_cats.shape)
print(_cats[0][0][0])
# Out:
# <class 'numpy.ndarray'>
# (4005, 404, 360, 3)
# [0.9176 0.8588 0.9843]
# <class 'numpy.ndarray'>
# (4000, 404, 360, 3)
# [0.0863 0.1216 0.1608]

# %%
randomIds = [np.random.randint(0,4000,15)]
print(randomIds)
sampleDog = [dog for dog in _dogs[randomIds]]

fig,axes = plt.subplots(3,5,figsize=(16,8))

for i in range(15):
    axes[i//5][i%5].imshow(sampleDog[i])
plt.tight_layout()
# Out:
# [array([3397, 1760,  490, 1337,  969, 2527, 3341,  142, 2433, 3785, 1463,
#        2347, 3265,  244, 2433])]
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
class aaa():
    def __init__(self,word):
        self.word = word
        self.type = 'aaa'

# %%
aa = aaa('oh')
print(aa.type)
print(aa.word)
# Out:
# aaa
# oh

# %% [markdown]
# ## dog and cat classifier

# %%
from keras.models import Sequential()

# %%
class classifier():
    def __init__(self,trainTrain,trainTrainLabel,trainValid,trainValidLabel):
        self.trainTrain = trainTrain
        self.trainTrainLabel = trainTrainLabel
        self.trainValid = trainValid
        self.trainValidLabel = trainValidLabel
        
    def train(self):
        model = Sequential()
        
        
        
        self.trainTrain +=1
        self.trainValid +=1

# %%
sample = classifier(1,1,2,2)
print(sample.trainTrain)
print(sample.trainValid)

sample.train()
print(sample.trainTrain)
print(sample.trainValid)
# Out:
# 1
# 2
# 2
# 3

# %%
import numpy as np
import cv2
import matplotlib.image as maping
import matplotlib.pyplot as plt

# %%
ls
# Out:
# RegularSizedCatsImages.npy  TryAndErrorNote.ipynb
# RegularSizedDogsImages.npy  __pycache__/
# ResizedCatImg.npy           model.py
# ResizedDogImg.npy           test_set/
# SetUpTheOriginalData.py     training_set/

# %%
dog = np.load('ResizedDogImg.npy')

# %%
dog.shape
# Out:
# (4005, 404, 360, 3)

# %%
cat = np.load('ResizedCatImg.npy')

# %%
cat.shape
# Out:
# (4000, 404, 360, 3)

# %%
cat[0].shape
# Out:
# (404, 360, 3)

# %%
aaa = cv2.resize(cat[0],dsize=(32,32))

# %%
plt.imshow(aaa)

# %%
plt.imshow(cat[0])
